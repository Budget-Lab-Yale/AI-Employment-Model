# %%
from clean_output import clean_output
from clean_crosswalk import  clean_crosswalk
import os

# %%
clean_output(
    "/nfs/roberts/project/pi_nrs36/shared/model_data/AI-Employment-Model/output/202606101347", 
    "/nfs/roberts/project/pi_nrs36/jmk263/Repositories/interactives-staging/tools/ai-labor-market-tracker/data",
    "/nfs/roberts/project/pi_nrs36/jmk263/Repositories/AI-Effects/output/202605061428"
    )
# Out:
# Writing outputs to tracker repo on git branch: 'test_auto'  (/nfs/roberts/project/pi_nrs36/jmk263/Repositories/interactives-staging/tools/ai-labor-market-tracker/data)

# %%
clean_crosswalk(
    "../resources",
    "/nfs/roberts/project/pi_nrs36/jmk263/Repositories/interactives-staging/tools/ai-labor-market-tracker/data/crosswalks"
)
# Out:
# Writing outputs to tracker repo on git branch: 'test_auto'  (/nfs/roberts/project/pi_nrs36/jmk263/Repositories/interactives-staging/tools/ai-labor-market-tracker/data/crosswalks)
# ...
# PCA WEIGHTS (WITHOUT WEBB)
# ...
#
# PCA Weights (All Measures):
# soc2018
#                Measure  PCA Weight
#         dv_rating_beta    0.426283
#      human_rating_beta    0.424542
#    genaiexp_estz_total    0.418828
#                   AIOE    0.410025
#     genaiexp_estz_core    0.407267
# ai_applicability_score    0.358669
#
# Variance explained by PC1: 79.48%
# ...
# PCA WEIGHTS (WITHOUT WEBB)
# ...
#
# PCA Weights (All Measures):
# cps_code
#                Measure  PCA Weight
#         dv_rating_beta    0.426337
#      human_rating_beta    0.424835
#    genaiexp_estz_total    0.418919
#                   AIOE    0.412216
#     genaiexp_estz_core    0.406499
# ai_applicability_score    0.356505
#
# Variance explained by PC1: 80.01%
